# %% [markdown]
# <a href="https://colab.research.google.com/github/BoddiReddyShivani/batch-45-46/blob/main/lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as nd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Update the file path if needed
file_path = '/content/pp.txt'

try:
    # Read the data from the file (assuming it's tab-separated)
    df1 = pd.read_csv(file_path, sep='\t')
    print(df1)  # Display the DataFrame
except FileNotFoundError:
    print(f"File '{file_path}' not found.")
except pd.errors.EmptyDataError:
    print(f"File '{file_path}' is empty or contains no data.")
except pd.errors.ParserError:
    print(f"Error parsing data from '{file_path}'. Check the file format.")
# Out:
#   First line: This is a test file
# 0             This is second line
# 1                      third line
# 2          and subsiquent lines..
# 3                      and more..

# %%
df2= pd.read_table('/content/Spd.csv')
df2
# Out:
#      StudentID,Age,Gender,Ethnicity,ParentalEducation,StudyTimeWeekly,Absences,Tutoring,ParentalSupport,Extracurricular,Sports,Music,Volunteering,GPA,GradeClass
# 0     1001,17,1,0,2,19.833722807854713,7,1,2,0,0,1,0...
# 1     1002,18,0,0,1,15.40875605584674,0,0,1,0,0,0,0,...
# 2     1003,15,0,2,3,4.21056976881226,26,0,2,0,0,0,0,...
# 3     1004,17,1,0,3,10.028829473958215,14,0,3,1,0,0,...
# 4     1005,17,1,0,2,4.6724952729713305,17,1,3,0,0,0,...
# ...                                                 ...
# 2387  3388,18,1,0,3,10.680554607694354,2,0,4,1,0,0,0...
# 2388  3389,17,0,0,1,7.583217279598868,4,1,4,0,1,0,0,...
# 2389  3390,16,1,0,2,6.8054996446806175,20,0,2,0,0,0,...
# 2390  3391,16,1,1,0,12.416652655483858,17,0,2,0,1,1,...
# 2391  3392,16,1,0,2,17.819907492885296,13,0,2,0,0,0,...
#
# [2392 rows x 1 columns]

# %%
df3= pd.read_excel('/content/Historicalinvesttemp.xlsx')
df3
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
import numpy as np
list1=[1,2,3,]
array1 = np.array(list1)
array1
type(list1)
type(array1)
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1:",array2/array1)
print("array2 raised to the power of array1:",array2**array1)
print(f"{array2}raised to the power of {array1}:,{array2**array1}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1: [3.         1.         0.33333333]
# array2 raised to the power of array1: [3 4 1]
# [3 2 1]raised to the power of [1 2 3]:,[3 4 1]

# %%
#sine fuction
print("sine:",np.sin(array1))
# Out:
# sine: [0.84147098 0.90929743 0.14112001]

# %%
#logarithm
print("natural logarithm:",np.log(array1))
print("base-10 logarithm:",np.log10(array1))
print("base-2 logarithm:",np.log2(array1))
# Out:
# natural logarithm: [0.         0.69314718 1.09861229]
# base-10 logarithm: [0.         0.30103    0.47712125]
# base-2 logarithm: [0.        1.        1.5849625]

# %%
#exponential
print("exponential:",np.exp(array1))
# Out:
# exponential: [ 2.71828183  7.3890561  20.08553692]

# %%
print("adding of numpy array{array1} and {array2}togther:",array1+array2)
# Out:
# adding of numpy array{array1} and {array2}togther: [4 4 4]

# %%
people=['ann','brandan','chen','kavya','shivani','neha',]
age=[12,13,14,15,16,17]
weight=[55,45,67,45,33,44]
height=[160,216,170,130,120,140]

# %%
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight in kilos")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='pink',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight(in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("histogram of patitent weight",fontsize=18)
plt.xlabel("weight in kgs",fontsize=15)
plt.show()
